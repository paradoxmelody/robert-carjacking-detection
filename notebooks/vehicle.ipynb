# %% [markdown]
# EDA FOR VEHCILE DATA

# %%
import numpy as np   
import pandas as pd  
import seaborn as sns
import matplotlib as plt
#to ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#read the dataset
df = pd.read_csv("../data/Vehicle_Data.csv")

# %%
 
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 949 entries, 0 to 948
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   IMEI    949 non-null    int64
#  1   Make    948 non-null    str
#  2   Model   948 non-null    str
#  3   Colour  948 non-null    str
#  4   Year    948 non-null    float64
#  5   Age     921 non-null    float64
#  6   Gender  921 non-null    str
# dtypes: float64(2), int64(1), str(4)
# memory usage: 52.0 KB
#                IMEI         Year         Age
# count  9.490000e+02   948.000000  921.000000
# mean   8.649012e+14  2018.279536   47.857763
# std    4.276071e+12     4.627511   10.896567
# min    8.603051e+14  2003.000000   26.000000
# 25%    8.603051e+14  2015.000000   39.000000
# 50%    8.647141e+14  2019.000000   47.000000
# 75%    8.697161e+14  2022.000000   56.000000
# max    8.697161e+14  2024.000000   74.000000

# %%
#check for unique values and null
df.nunique()

df.isnull().sum(
)
# Out:
# IMEI       0
# Make       1
# Model      1
# Colour     1
# Year       1
# Age       28
# Gender    28
# dtype: int64

# %%
#car makes distribution
df['Make'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Make'>

# %%
#colour distribution
df['Colour'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Colour'>

# %%
#age distribution of drivers
df['Age'].hist(bins=20)
# Out:
# <Axes: >

# %%
#Gender split
df['Gender'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: >

# %%
#year of vehicles
df['Year'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='Year'>
